# %%
from googleapiclient.discovery import build
import pandas as pd
import time

# Initialize YouTube API
youtube = build('youtube', 'v3', developerKey='***************************************')

def split_list(lst, n):
    for i in range(0, len(lst), n):
        yield lst[i:i + n]

def fetch_replies(comment_id, video_id):
    replies = []
    try:
        request = youtube.comments().list(part="snippet", parentId=comment_id, maxResults=50)
        while request:
            response = request.execute()
            for item in response.get("items", []):
                reply = item["snippet"]
                replies.append({
                    "video_id": video_id,
                    "comment_id": comment_id,
                    "reply_id": item["id"],
                    "text": reply["textDisplay"],
                    "author": reply["authorDisplayName"],
                    "published_at": reply["publishedAt"],
                    "like_count": reply["likeCount"]
                })
            request = youtube.comments().list_next(request, response)
            time.sleep(1)
    except Exception as e:
        print(f"Error fetching replies for comment {comment_id}: {e}")
    return replies

def fetch_comments(video_id):
    comments = []
    try:
        request = youtube.commentThreads().list(part="snippet", videoId=video_id, maxResults=100)
        while request:
            response = request.execute()
            for item in response.get("items", []):
                comment = item["snippet"]["topLevelComment"]["snippet"]
                comments.append({
                    "video_id": video_id,
                    "comment_id": item["id"],
                    "text": comment["textDisplay"],
                    "author": comment["authorDisplayName"],
                    "published_at": comment["publishedAt"],
                    "like_count": comment["likeCount"],
                    "reply_count": item["snippet"]["totalReplyCount"]
                })
                if item["snippet"]["totalReplyCount"] > 0:
                    comments.extend(fetch_replies(item["id"], video_id))
            request = youtube.commentThreads().list_next(request, response)
            time.sleep(1)
    except Exception as e:
        print(f"Error fetching comments for video {video_id}: {e}")
    return comments

def fetch_video_details(video_ids):
    video_details = []
    for chunk in split_list(video_ids, 50):
        video_ids_str = ','.join(chunk)
        response = youtube.videos().list(part="snippet", id=video_ids_str).execute()
        video_details.extend(response.get('items', []))
    return video_details

def search_videos(query="تأثير الذكاء الاصطناعي على فرص العمل", max_results=100):
    try:
        videos = []
        video_ids = []
        request = youtube.search().list(part="id,snippet", q=query, maxResults=min(max_results, 50), type="video")

        while request and len(video_ids) < max_results:
            response = request.execute()
            for item in response.get('items', []):
                video_id = item['id']['videoId']
                video_title = item['snippet']['title']
                video_ids.append(video_id)
                videos.append({"id": video_id, "title": video_title, "category_name": "Fetching..."})
                if len(video_ids) >= max_results:
                    break
            request = youtube.search().list_next(request, response)

        print(f"Found {len(video_ids)} videos.")

        if video_ids:
            video_details = fetch_video_details(video_ids)
            for video in videos:
                video_detail = next((item for item in video_details if item['id'] == video['id']), None)
                if video_detail:
                    video['category_name'] = "اجتماعي"

        video_ids_df = pd.DataFrame(videos)
        return video_ids_df

    except Exception as e:
        print(f"Error searching videos: {e}")
        return pd.DataFrame()

def fetch_all_comments(video_ids, target_count=6000):
    all_comments = []
    seen = set()

    for idx, video_id in enumerate(video_ids):
        print(f"Fetching comments for video {idx+1}/{len(video_ids)}: {video_id}")
        comments = fetch_comments(video_id)

        for comment in comments:
            key = (comment["text"], comment["author"], comment["published_at"])
            if key not in seen:
                seen.add(key)
                all_comments.append(comment)

        print(f"Collected {len(all_comments)} unique comments so far.")
        if len(all_comments) >= target_count:
            break

    return all_comments

# Run the full process
video_ids_df = search_videos(max_results=100)
video_ids = video_ids_df['id'].tolist()

if not video_ids:
    raise ValueError("Failed to retrieve video IDs.")

comments_data = fetch_all_comments(video_ids, target_count=6000)

df_comments = pd.DataFrame(comments_data)
df_comments.drop_duplicates(subset=["text", "author", "published_at"], inplace=True)
df_comments = df_comments.head(6000)
df_comments.to_excel("dataset.xlsx", index=False)
print("✅ Finished. Dataset saved as dataset.xlsx with", len(df_comments), "unique comments.")
# Out:
# Found 100 videos.
# Fetching comments for video 1/100: rOcT2cySbdk
# Collected 0 unique comments so far.
# Fetching comments for video 2/100: i42gPtjXnKU
# Collected 59 unique comments so far.
# Fetching comments for video 3/100: c6hQ9DcNPyA
# Collected 59 unique comments so far.
# Fetching comments for video 4/100: GWnV2zUtIrQ
# Collected 60 unique comments so far.
# Fetching comments for video 5/100: TJCnKwSc34M
# Collected 68 unique comments so far.
# Fetching comments for video 6/100: 3Py4uJ6BTP8
# Collected 71 unique comments so far.
# Fetching comments for video 7/100: F7kvnJwe_5Y
# Collected 71 unique comments so far.
# Fetching comments for video 8/100: EYDTuI1grp8
# Collected 81 unique comments so far.
# Fetching comments for video 9/100: YTJ8HQJLf7Q
# Collected 81 unique comments so far.
# Fetching comments for video 10/100: ff0x8u9s3No
# Collected 81 unique comments so far.
# Fetching comments for video 11/100: M6Wk3Yj6MU8
# Collected 85 unique comments so far.
# Fetching comments for video 12/100: CyqFqEqXkXk
# Collected 85 unique comments so far.
# Fetching comments for video 13/100: hxD1cnMxbZs
# Collected 85 unique comments so far.
# Fetching comments for video 14/100: v7HFSZCgnrs
# Collected 327 unique comments so far.
# Fetching comments for video 15/100: k0svY8MoHiM
# Collected 332 unique comments so far.
# Fetching comments for video 16/100: ryWsTQRFUeI
# Collected 332 unique comments so far.
# Fetching comments for video 17/100: 45ctCWzYL_o
# Collected 332 unique comments so far.
# Fetching comments for video 18/100: yh1cENhZXBQ
# Collected 332 unique comments so far.
# Fetching comments for video 19/100: Ejr_czMsYVs
# Collected 332 unique comments so far.
# Fetching comments for video 20/100: x6DTrZWQtv4
# Collected 335 unique comments so far.
# Fetching comments for video 21/100: 2TwsUNXJZFQ
# Collected 506 unique comments so far.
# Fetching comments for video 22/100: zs0G0rnYDSQ
# Collected 506 unique comments so far.
# Fetching comments for video 23/100: 660rVipGBqE
# Collected 506 unique comments so far.
# Fetching comments for video 24/100: pPqzeCkyRn4
# Collected 506 unique comments so far.
# Fetching comments for video 25/100: EaMY1oDjU5s
# Collected 510 unique comments so far.
# Fetching comments for video 26/100: yS_b3ZS3k1M
# Collected 512 unique comments so far.
# Fetching comments for video 27/100: 8IAsVVUFCOM
# Collected 512 unique comments so far.
# Fetching comments for video 28/100: 91ATGtCQ6g8
# Collected 512 unique comments so far.
# Fetching comments for video 29/100: waiPCFz7qRA
# Collected 512 unique comments so far.
# Fetching comments for video 30/100: 1grKFMmEX2Y
# Collected 512 unique comments so far.
# Fetching comments for video 31/100: oAvOYpogg7M
# Collected 516 unique comments so far.
# Fetching comments for video 32/100: j8bxuvgzytU
# Collected 516 unique comments so far.
# Fetching comments for video 33/100: AGD2FerJWcI
# Collected 516 unique comments so far.
# Fetching comments for video 34/100: DXLnPmW9yuk
# Collected 516 unique comments so far.
# Fetching comments for video 35/100: EkjfqtlGR7I
# WARNING:googleapiclient.http:Encountered 403 Forbidden with reason "commentsDisabled"
# Collected 517 unique comments so far.
# Fetching comments for video 36/100: AeQZuT8XqN8
# Error fetching comments for video AeQZuT8XqN8: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=AeQZuT8XqN8&maxResults=100&key=AIzaSyDs0o4CML9Jze3dgnHxwpXRQq8MIueFV0w&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# Collected 517 unique comments so far.
# Fetching comments for video 37/100: 3ycGxnt1ofM
# Collected 528 unique comments so far.
# Fetching comments for video 38/100: KXUaqM6enhI
# Collected 528 unique comments so far.
# Fetching comments for video 39/100: 5GpyV6LayqU
# Collected 529 unique comments so far.
# Fetching comments for video 40/100: vx5sNC1AF1w
# Collected 529 unique comments so far.
# Fetching comments for video 41/100: jbRTCbx8Otc
# Collected 529 unique comments so far.
# Fetching comments for video 42/100: x27tYPUJ9Os
# Collected 555 unique comments so far.
# Fetching comments for video 43/100: et2GBh81yUI
# Collected 4016 unique comments so far.
# Fetching comments for video 44/100: IUHJWY8oGfI
# Collected 4017 unique comments so far.
# Fetching comments for video 45/100: mxSQurJ4IC4
# Collected 4017 unique comments so far.
# Fetching comments for video 46/100: OboNCsdZXSE
# Collected 4065 unique comments so far.
# Fetching comments for video 47/100: cK6eqGbVGd8
# Collected 4096 unique comments so far.
# Fetching comments for video 48/100: BI6yQSIs9Ew
# Collected 4124 unique comments so far.
# Fetching comments for video 49/100: IfZJW0fLrNA
# Collected 4129 unique comments so far.
# Fetching comments for video 50/100: jsIrcn0ovgk
# Collected 4131 unique comments so far.
# Fetching comments for video 51/100: IfZJW0fLrNA
# Collected 4131 unique comments so far.
# Fetching comments for video 52/100: jsIrcn0ovgk
# Collected 4131 unique comments so far.
# Fetching comments for video 53/100: aebXbbP-fmw
# Collected 4132 unique comments so far.
# Fetching comments for video 54/100: gbqQPY8hjek
# Collected 4135 unique comments so far.
# Fetching comments for video 55/100: kfDFfyb9Shc
# Collected 4135 unique comments so far.
# Fetching comments for video 56/100: Xc3oNRdibrI
# Collected 4135 unique comments so far.
# Fetching comments for video 57/100: -41FWKbeGl0
# Collected 4137 unique comments so far.
# Fetching comments for video 58/100: aWeIcIKjMTg
# Collected 4137 unique comments so far.
# Fetching comments for video 59/100: xgNefQ2Ravk
# Collected 4148 unique comments so far.
# Fetching comments for video 60/100: XZ_nd2BCsr8
# Collected 4148 unique comments so far.
# Fetching comments for video 61/100: CRnXdqBDUNE
# Collected 4151 unique comments so far.
# Fetching comments for video 62/100: it4FUXBMA9Q
# Collected 4151 unique comments so far.
# Fetching comments for video 63/100: W9gzuTWLOuY
# Collected 4151 unique comments so far.
# Fetching comments for video 64/100: lN80mIW_Xyk
# Collected 4151 unique comments so far.
# Fetching comments for video 65/100: h-zvueeUICY
# Collected 4153 unique comments so far.
# Fetching comments for video 66/100: 4Z7U-VQsht4
# Collected 4153 unique comments so far.
# Fetching comments for video 67/100: TigfQmxTwI0
# Collected 4156 unique comments so far.
# Fetching comments for video 68/100: lf0LrtaW6Ig
# Collected 4158 unique comments so far.
# Fetching comments for video 69/100: aCqz5tWl8Ls
# Collected 4158 unique comments so far.
# Fetching comments for video 70/100: z-erlYHgrsU
# Collected 4165 unique comments so far.
# Fetching comments for video 71/100: 59MzuOpCG9w
# Collected 4165 unique comments so far.
# Fetching comments for video 72/100: 4W8kKC0pP4E
# Collected 4165 unique comments so far.
# Fetching comments for video 73/100: jH4b0X6AwsE
# Collected 4170 unique comments so far.
# Fetching comments for video 74/100: h8rggLzZPCA
# Collected 4173 unique comments so far.
# Fetching comments for video 75/100: ZnAeLLA46t0
# Collected 4173 unique comments so far.
# Fetching comments for video 76/100: JCOhUjcd_kU
# Collected 4173 unique comments so far.
# Fetching comments for video 77/100: CEs2VKp8ip4
# Collected 4173 unique comments so far.
# Fetching comments for video 78/100: -gB0w4AdKrM
# Collected 4174 unique comments so far.
# Fetching comments for video 79/100: 8G18Po3EkIc
# Collected 4174 unique comments so far.
# Fetching comments for video 80/100: 7D_81oY8iLw
# Collected 4174 unique comments so far.
# Fetching comments for video 81/100: ViR1z3i3nwQ
# Collected 6663 unique comments so far.
# ✅ Finished. Dataset saved as dataset.xlsx with 6000 unique comments.

# %%
df=df_comments
df.head()
# Out:
#       video_id                  comment_id  \
# 0  i42gPtjXnKU  Ugx_Q8PlXv97CVWcMIx4AaABAg
# 1  i42gPtjXnKU  UgyGhgu6v4J4CRpWAH14AaABAg
# 2  i42gPtjXnKU  Ugx03OLTGdO__aX7QrJ4AaABAg
# 3  i42gPtjXnKU  UgwFLW4Mkaw3CLt7hRV4AaABAg
# 4  i42gPtjXnKU  UgyH3VDFYSrXp6xp0pZ4AaABAg
#
#                                                 text                author  \
# 0                       الموسيقى أعلى من صوت المذيعة      @ahmedmohsen6737
# 1  علشان الذكاء الإصطناعي يحل محل الإنسان لازم يب...  @LionheartedProGamer
# 2  هل الذكاء الإصطناعي يمكنه التغلب على سوق الدعا...        @Qusaivonscham
# 3  كم بعد ابتعدت عن الله بسبب عرض النساء المتبرجا...      @عليمهديحسين-ت5ح
# 4  هذا ما يسمى صناعة المستبل وتوجيهه حسب رغبات ال...           @Azawadtube
#
#            published_at  like_count  reply_count reply_id
# 0  2025-05-15T10:29:22Z           0          0.0      NaN
# 1  2025-04-18T18:22:41Z           0          0.0      NaN
# 2  2025-04-12T03:55:07Z           0          0.0      NaN
# 3  2025-03-20T19:46:41Z           0          0.0      NaN
# 4  2025-03-09T10:58:44Z           0          0.0      NaN

# %%
df.drop(columns=['video_id','comment_id','reply_count','author','published_at','like_count','reply_id'],inplace=True)

# %%
df.head()
# Out:
#                                                 text
# 0                       الموسيقى أعلى من صوت المذيعة
# 1  علشان الذكاء الإصطناعي يحل محل الإنسان لازم يب...
# 2  هل الذكاء الإصطناعي يمكنه التغلب على سوق الدعا...
# 3  كم بعد ابتعدت عن الله بسبب عرض النساء المتبرجا...
# 4  هذا ما يسمى صناعة المستبل وتوجيهه حسب رغبات ال...

# %%
df.tail()
# Out:
#                                                    text
# 5995                              انت كده عسل وحلو يعني
# 5996  انا شفت نفس المقطع فين قبل كده🤔<br>كل صناع الم...
# 5997  @naiseok2875 <br>سواء هي ولا هو مش هتفرق لان ا...
# 5998                                   لسه كنت هقول كده
# 5999                                       كلامك صح جدا

# %% [markdown]
# # **Extracts Arabic words from each text in the DataFrame by keeping only Arabic characters.**

# %%
import re
def extract_arabic(text):
    if not isinstance(text, str):
        return ""
    arabic_words = re.findall(r'[\u0600-\u06FF]+', text)
    return ' '.join(arabic_words)
df['text'] = df['text'].apply(extract_arabic)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    6000 non-null   object
# dtypes: object(1)
# memory usage: 47.0+ KB

# %% [markdown]
# # **Removes rows where the Arabic text contains only one word (to avoid keeping short or possibly offensive words(it's our choice !).**

# %%
df = df[df['text'].str.split().str.len() > ]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5262 entries, 0 to 5999
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    5262 non-null   object
# dtypes: object(1)
# memory usage: 82.2+ KB

# %% [markdown]
# # **EXPORTING**

# %%
df.to_excel('cleaned_dataset.xlsx', index=False)

# %% [markdown]
# # **MACHINE LEARNING !!!**

# %% [markdown]
# **Part I - Data Loading and Preprocessing✅**

# %% [markdown]
# **Part II - Train-Test Split & TF-IDF Vectorization**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from sklearn.pipeline import make_pipeline
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle

# %% [markdown]
# # 📥 Load Dataset

# %%
df = pd.read_excel("cleaned_dataset (1).xlsx")

# %%
df.head()
# Out:
#                                                 text     label
# 0                       الموسيقى أعلى من صوت المذيعة   neutral
# 1  علشان الذكاء الإصطناعي يحل محل الإنسان لازم يب...   neutral
# 2  هل الذكاء الإصطناعي يمكنه التغلب على سوق الدعا...   neutral
# 3  كم بعد ابتعدت عن الله بسبب عرض النساء المتبرجا...  negative
# 4  هذا ما يسمى صناعة المستبل وتوجيهه حسب رغبات ال...  negative

# %% [markdown]
# # 🏷️ Encode labels

# %%
label_encoder = LabelEncoder()
df['label_encoded'] = label_encoder.fit_transform(df['label'])

# %% [markdown]
# # 📊 Train-Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df['text'], df['label_encoded'], test_size=0.2, random_state=42
)

# %% [markdown]
# # ⚠️ Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(ngram_range=(1, 2), max_features=7000)
X_train = tfidf.fit_transform(X_train)
X_test = tfidf.transform(X_test)

# %% [markdown]
# # **Part III - Model Training & Evaluation**

# %%
#Model Initialization
nb_model         = GaussianNB()
nn_model         = MLPClassifier(hidden_layer_sizes=(100,), activation='logistic', solver='adam', max_iter=500)
linear_svm_model = SVC(kernel='linear')
rbf_svm_model    = SVC(kernel='rbf')
poly_svm_model   = SVC(kernel='poly', degree=2)
sgd_svm_model    = SVC(kernel='sigmoid')

#Naive Bayes needs dense input
X_train_dense = X_train.toarray()
X_test_dense = X_test.toarray()

# Model Training
nb_model.fit(X_train_dense, y_train)
nn_model.fit(X_train, y_train)
linear_svm_model.fit(X_train, y_train)
rbf_svm_model.fit(X_train, y_train)
poly_svm_model.fit(X_train, y_train)
sgd_svm_model.fit(X_train, y_train)

#   Model Prediction
nb_pred         = nb_model.predict(X_test_dense)
nn_pred         = nn_model.predict(X_test)
linear_svm_pred = linear_svm_model.predict(X_test)
rbf_svm_pred    = rbf_svm_model.predict(X_test)
poly_svm_pred   = poly_svm_model.predict(X_test)
sgd_svm_pred    = sgd_svm_model.predict(X_test)

# Evaluation
print("Naive Bayes:\n", classification_report(y_test, nb_pred, target_names=label_encoder.classes_))
print("Neural Net:\n", classification_report(y_test, nn_pred, target_names=label_encoder.classes_))
print("Linear SVM:\n", classification_report(y_test, linear_svm_pred, target_names=label_encoder.classes_))
print("RBF SVM:\n", classification_report(y_test, rbf_svm_pred, target_names=label_encoder.classes_))
print("Poly SVM:\n", classification_report(y_test, poly_svm_pred, target_names=label_encoder.classes_))
print("Sigmoid SVM:\n", classification_report(y_test, sgd_svm_pred, target_names=label_encoder.classes_))
# Out:
# Naive Bayes:
#                precision    recall  f1-score   support
#
#     negative       0.66      0.55      0.60       477
#      neutral       0.28      0.45      0.34       177
#     positive       0.78      0.73      0.75       470
#
#     accuracy                           0.61      1124
#    macro avg       0.57      0.57      0.56      1124
# weighted avg       0.65      0.61      0.62      1124
#
# Neural Net:
#                precision    recall  f1-score   support
#
#     negative       0.70      0.73      0.72       477
#      neutral       0.39      0.42      0.40       177
#     positive       0.82      0.76      0.79       470
#
#     accuracy                           0.69      1124
#    macro avg       0.64      0.64      0.64      1124
# weighted avg       0.70      0.69      0.70      1124
#
# Linear SVM:
#                precision    recall  f1-score   support
#
#     negative       0.66      0.89      0.76       477
#      neutral       0.54      0.28      0.37       177
#     positive       0.89      0.73      0.80       470
#
#     accuracy                           0.73      1124
#    macro avg       0.70      0.64      0.64      1124
# weighted avg       0.74      0.73      0.72      1124
#
# RBF SVM:
#                precision    recall  f1-score   support
#
#     negative       0.61      0.94      0.74       477
#      neutral       0.66      0.16      0.26       177
#     positive       0.93      0.69      0.79       470
#
#     accuracy                           0.71      1124
#    macro avg       0.73      0.60      0.60      1124
# weighted avg       0.75      0.71      0.69      1124
#
# Poly SVM:
#                precision    recall  f1-score   support
#
#     negative       0.60      0.95      0.74       477
#      neutral       0.64      0.15      0.25       177
#     positive       0.94      0.67      0.78       470
#
#     accuracy                           0.71      1124
#    macro avg       0.73      0.59      0.59      1124
# weighted avg       0.75      0.71      0.68      1124
#
# Sigmoid SVM:
#                precision    recall  f1-score   support
#
#     negative       0.65      0.91      0.76       477
#      neutral       0.61      0.26      0.36       177
#     positive       0.90      0.73      0.80       470
#
#     accuracy                           0.73      1124
#    macro avg       0.72      0.63      0.64      1124
# weighted avg       0.75      0.73      0.72      1124

# %% [markdown]
# # **Saving Linear SVM model (it has the highest score )✅**

# %%
with open("bestModel.pickle", "wb") as f:
    pickle.dump(linear_svm_model, f)

print("Best model (Linear SVM) pipeline saved as bestModel.pickle")
# Out:
# Best model (Linear SVM) pipeline saved as bestModel.pickle
